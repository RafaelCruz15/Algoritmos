# %% [markdown]
# # Matriz sin utilizar la libreria numpy

# %%
import time

# crea la matriz cuadrada de un tamaño y valor cualquiera
def array(tam, valor):
    A = []

    # llena la matriz de 0's
    for i in range(0, tam):
        A.append([0] * tam)

    # llena la matriz de el valor que digiten
    for i in range(0, tam):
        for j in range(0, tam):
            A[i][j] = valor

    return A

# multiplica la matriz
def mult_matriz(A, B):
    C = []
    for i in range(len(A)):
        C.append([0] * (len(B[0])))

    for i in range(len(A)):
        for j in range(len(B)):
            for k in range(len(B[0])):
                C[i][j] += A[i][k] * B[k][j]
    return C

def promedio(array):
    sum = 0.0
    for i in range(0, len(array)):
        sum = sum + array[i]
    return sum / len(array)

n = []
# arreglo de tamaño n = 50, 100, 150, 200, ... , 500
for i in range(50, 550, 50):
    n.append(i)

# almacena los valores para cada n
t_50 = []
t_100 = []
t_150 = []
t_200 = []
t_250 = []
t_300 = []
t_350 = []
t_400 = []
t_450 = []
t_500 = []

# usamos tamaños de n = 10, 20, 30, 40, ... , 100
for i in range(15):
    for j in range(50, 550, 50):
        mat1 = (array(j, 1))
        mat2 = (array(j, 2))

        start_time = time.time()  # tiempo inicial
        solucion = mult_matriz(mat1, mat2)
        tiempo = (time.time() - start_time)

        # pregunta donde esta j para almacenar el tiempo de acuerdo a n
        if (j == 50):
            t_50.append(tiempo)
        elif (j == 100):
            t_100.append(tiempo)
        elif (j == 150):
            t_150.append(tiempo)
        elif (j == 200):
            t_200.append(tiempo)
        elif (j == 250):
            t_250.append(tiempo)
        elif (j == 300):
            t_300.append(tiempo)
        elif (j == 350):
            t_350.append(tiempo)
        elif (j == 400):
            t_400.append(tiempo)
        elif (j == 450):
            t_450.append(tiempo)
        elif (j == 500):
            t_500.append(tiempo)

        #print("El tiempo para ", j, " es de ", tiempo)

# sacamos el promedio y almacenamos en un nuevo arreglo
t_final = []
t_final.append(promedio(t_50))
t_final.append(promedio(t_100))
t_final.append(promedio(t_150))
t_final.append(promedio(t_200))
t_final.append(promedio(t_250))
t_final.append(promedio(t_300))
t_final.append(promedio(t_350))
t_final.append(promedio(t_400))
t_final.append(promedio(t_450))
t_final.append(promedio(t_500))
#print(t_final)

# tiempos promedios
for i in range(10):
    print("Para n = " , n[i] , " tenemos un tiempo promedio de ",  t_final[i])
# Out:
# ('Para n = ', 50, ' tenemos un tiempo promedio de ', 0.02551240921020508)
# ('Para n = ', 100, ' tenemos un tiempo promedio de ', 0.1728743553161621)
# ('Para n = ', 150, ' tenemos un tiempo promedio de ', 0.5674927711486817)
# ('Para n = ', 200, ' tenemos un tiempo promedio de ', 1.3293159484863282)
# ('Para n = ', 250, ' tenemos un tiempo promedio de ', 2.5255618572235106)
# ('Para n = ', 300, ' tenemos un tiempo promedio de ', 4.474226188659668)
# ('Para n = ', 350, ' tenemos un tiempo promedio de ', 7.216175492604574)
# ('Para n = ', 400, ' tenemos un tiempo promedio de ', 10.688867791493733)
# ('Para n = ', 450, ' tenemos un tiempo promedio de ', 15.564555104573568)
# ('Para n = ', 500, ' tenemos un tiempo promedio de ', 20.884686962763467)
